# %%
from covid_seird import CountryCovidSeird

# %%
us = CountryCovidSeird('us')

# %%
us.code
# Out:
# 'US'

# %%
us.name
# Out:
# 'US'

# %%
us.population
# Out:
# 327167434

# %%
us.data
# Out:
#                       confirmed  deaths
# 2020-01-22T00:00:00Z          1       0
# 2020-01-23T00:00:00Z          1       0
# 2020-01-24T00:00:00Z          2       0
# 2020-01-25T00:00:00Z          2       0
# 2020-01-26T00:00:00Z          5       0
# ...                         ...     ...
# 2020-05-26T00:00:00Z    1680913   98912
# 2020-05-27T00:00:00Z    1699176  100417
# 2020-05-28T00:00:00Z    1721753  101616
# 2020-05-29T00:00:00Z    1746019  102809
# 2020-05-30T00:00:00Z    1770165  103776
#
# [130 rows x 2 columns]

# %%
us.fit()

# %%
us.r0
# Out:
# 2.194082129927714

# %%
us.r2
# Out:
# 0.49896970188974227

# %%
us.plot_fit('fit')

# %%
us.simulation(days_ahead=150)

# %%
us.curves
# Out:
# {'susceptible': array([9.99999997e-01, 9.99999996e-01, 9.99999995e-01, 9.99999994e-01,
#         9.99999992e-01, 9.99999991e-01, 9.99999989e-01, 9.99999987e-01,
#         9.99999985e-01, 9.99999983e-01, 9.99999980e-01, 9.99999977e-01,
#         9.99999974e-01, 9.99999970e-01, 9.99999965e-01, 9.99999960e-01,
#         9.99999955e-01, 9.99999948e-01, 9.99999941e-01, 9.99999933e-01,
#         9.99999924e-01, 9.99999914e-01, 9.99999903e-01, 9.99999889e-01,
#         9.99999875e-01, 9.99999859e-01, 9.99999840e-01, 9.99999819e-01,
#         9.99999795e-01, 9.99999769e-01, 9.99999739e-01, 9.99999705e-01,
#         9.99999666e-01, 9.99999623e-01, 9.99999574e-01, 9.99999521e-01,
#         9.99999458e-01, 9.99999388e-01, 9.99999308e-01, 9.99999220e-01,
#         9.99999122e-01, 9.99999008e-01, 9.99998879e-01, 9.99998734e-01,
#         9.99998575e-01, 9.99998394e-01, 9.99998186e-01, 9.99997951e-01,
#         9.99997687e-01, 9.99997397e-01, 9.99997068e-01, 9.99996694e-01,
# ...

# %%
us.plot_simulation('simulation')
